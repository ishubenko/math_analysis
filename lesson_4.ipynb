# %% [markdown]
# ## Тема “Предел функции”

# %% [markdown]
# #### 1.
# Предложить пример функции, не имеющей предела в нуле и в бесконечностях.

# %% [markdown]
# $$ f(x) =1+ \frac{1}{x} $$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-10,10,50)
y = 1+1/x
fig = plt.plot(x, y)
# plt.ylim((0,5))
plt.show()

# %%
x = np.linspace(-10,10,50)
y = 100+2**x
fig = plt.plot(x, y)
# plt.ylim((0,5))
plt.show()

# %%
x = np.linspace(0,10,80)
y = 2 + np.sqrt(x)
fig = plt.plot(x, y)
plt.ylim((0,5))
plt.show()

# %% [markdown]
# Вероятно, чтобы функция не имела пределов в 0 или $\pm \infty$ потребуется ограничить значения x

# %% [markdown]
# #### 2.
# Привести пример функции, не имеющей предела в точке, но определенной в ней.

# %% [markdown]
# #### 3.
# Исследовать функцию  $f(x)= x^3 - x^2$ по плану:

# %%
x = np.linspace(-20,20,300)
y = x**3 - x**2
fig = plt.plot(x, y)
plt.ylim((-2,2))
plt.xlim((-2,2))
plt.grid(True)
plt.show()

# %% [markdown]
# a. Область задания и область значений
# $$x \in (-\infty;+\infty); y \in (-\infty;+\infty)$$

# %% [markdown]
# b. Нули функции и их кратность.
# y=0 при x=0, x=1

# %% [markdown]
# C. Отрезки знакопостоянства.
# при x<1 y<0, при x>1 y>0

# %% [markdown]
# d. Интервалы монотонности.
# убывает при $$x \in (0;\approx 0.6)$$
# возрастает при $$x \in (-\infty;0) и \in (\approx 0.6;+\infty)$$

# %% [markdown]
# e. Четность функции. обычная
# $$f(x)\neq f(-x); f(x)\neq -f(x)$$

# %% [markdown]
# f. Ограниченность.

# %% [markdown]
# g. Периодичность.
# Не периодочна

# %% [markdown]
# #### 4.
# Найти предел:

# %% [markdown]
# $$\lim_{x\to \infty} \frac{3x^3 - 2x^2}{4x^2} = \frac{2x^2(\frac{3}{2}x - 1)}{2x^2*2)}=\frac{1.5x-1}{2}=+\infty$$

# %% [markdown]
# $$\lim_{x\to \infty} \frac{\sqrt{1+x}-1}{\sqrt[3]{{1+x}}-1}=\frac{(1+x)^{\frac{3}{6}}-1}{(1+x)^\frac{2}{6}-1} = \frac{(1+x)^{\frac{3}{6}}-1} {(1+x)^\frac{2}{6}-1} * \frac{(1+x)^{\frac{3}{6}}+1} {(1+x)^{\frac{3}{6}}+1} = \frac{1+x-1}{(1+x)^{\frac{2}{3}}-1} =\approx \frac{x^6}{x^5} = +\infty$$

# %% [markdown]
# ## Тема “Теоремы о пределах”

# %% [markdown]
# $$\lim_{x\to 0} \frac{\sin{(2x)}}{4x} = \frac{2*\sin{(2x)}} {4*(2x)} =\frac{1}{2}$$

# %% [markdown]
# $$\lim_{x\to 0} \frac{x}{\sin{(x)}} = (\frac{0}{0})=1 $$

# %% [markdown]
# $$\lim_{x\to 0} \frac{x}{\arcsin{(x)}} = $$
